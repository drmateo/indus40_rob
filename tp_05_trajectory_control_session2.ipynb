# %% [markdown]
# # TP 05 - SESSION 2: Cartesian Trajectories and Control
#
# **Duration:** 4 hours
# **Exercises:** 4-6
#
# ---
#
# ## Session Goals
#
# By the end of this session, you will:
# - Plan trajectories in Cartesian (task) space
# - Implement PID control for joint tracking
# - Design and simulate a complete pick-and-place operation
#
# ---

# %%
# Setup
import numpy as np
import matplotlib.pyplot as plt
from roboticstoolbox import DHRobot, RevoluteDH
from roboticstoolbox import ctraj, jtraj
from spatialmath import SE3
import roboticstoolbox as rtb

plt.rcParams['figure.figsize'] = (12, 4)
print("Ready for Session 2!")

# %% [markdown]
# ## Exercise 4: Cartesian Space Trajectories
#
# ### Task
# Plan straight-line and circular motions in Cartesian space.
#
# ### Part A: Straight Line

# %%
# TODO: Create robot, define start/end poses, generate ctraj()
# Solve IK and plot results

# %% [markdown]
# ### Part B: Circular Path

# %%
# TODO: Generate circular trajectory, solve IK, plot

# %% [markdown]
# ## Exercise 5: PID Joint Control
#
# ### Task
# Implement and test PID controller for trajectory tracking.
#
# ### PID Controller Class

# %%
class PIDController:
    def __init__(self, Kp, Ki, Kd, dt):
        self.Kp = Kp
        self.Ki = Ki
        self.Kd = Kd
        self.dt = dt
        self.integral = 0
        self.prev_error = 0
    
    def compute(self, error, error_dot=None):
        # TODO: Implement PID equation
        pass

# TODO: Test with simulation

# %% [markdown]
# ## Exercise 6: Pick-and-Place Application
#
# ### Task
# Complete robotic task combining trajectory planning and control.

# %%
# TODO: 
# 1. Define waypoints
# 2. Generate trajectory
# 3. Simulate with PID
# 4. Visualize

# %% [markdown]
# ---
#
# ## TP 05 Complete!
#
# **Congratulations!** You've mastered trajectory planning and control fundamentals.
#
# ---
